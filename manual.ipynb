# %%
# 注册manual因子
import factors.manual  # noqa: F401

# %%
from factor_engine import get_factor

# %%
from factor_library import get_factor_library
factor_library = get_factor_library()

# %%
factor_name = "liquidity_momentum_deviation"

# %%
factor_library.manual_admit(
    spec=get_factor(factor_name),
)
